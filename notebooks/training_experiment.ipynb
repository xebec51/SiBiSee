# %% [markdown]
# # SiBiSee Training Experiment
#
# Notebook ini hanya menjadi entrypoint ringan. Training reproducible dijalankan melalui `scripts/train.py` dan konfigurasi YAML di `configs/training/`.
#
# Credential Roboflow wajib dibaca dari environment variable `ROBOFLOW_API_KEY`; jangan menulis API key literal di notebook atau commit Git.

# %%
import os

ROBOFLOW_API_KEY = os.environ["ROBOFLOW_API_KEY"]
ROBOFLOW_WORKSPACE = os.getenv("ROBOFLOW_WORKSPACE", "sibi-detection-nftzq")
ROBOFLOW_PROJECT = os.getenv("ROBOFLOW_PROJECT", "sibi-bieme")
ROBOFLOW_VERSION = int(os.getenv("ROBOFLOW_VERSION", "2"))

print("Roboflow configuration loaded from environment variables.")

# %%
# Optional dataset download. Jalankan hanya di environment pribadi.
# from roboflow import Roboflow
# rf = Roboflow(api_key=ROBOFLOW_API_KEY)
# project = rf.workspace(ROBOFLOW_WORKSPACE).project(ROBOFLOW_PROJECT)
# dataset = project.version(ROBOFLOW_VERSION).download("yolov8")
# print(dataset.location)
